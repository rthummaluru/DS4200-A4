# %%
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('table6 (1).xlsx')                            #You can also access it directly from github
df.head()   #Will return first 5 rows of the dataset
df
# Out:
#        Cleanup status Level       Value
# 0        With cleanup   Low   705209378
# 1     Without cleanup   Low   489883908
# 2  Benefit of cleanup   Low   215325469
# 3        With cleanup   Mid  1416705140
# 4     Without cleanup   Mid   879715684
# 5  Benefit of cleanup   Mid   536989457
# 6        With cleanup  High  2128200903
# 7     Without cleanup  High  1269547459
# 8  Benefit of cleanup  High   858653444

# %%
# Create the chart
chart = alt.Chart(df).mark_bar().encode(
    x='Cleanup status',
    y='Value',
    color='Level'
).properties(
    title='Cleanup status by Value of Ecosystem Services',
    width=600,
    height=400
)

chart
# Out:
# alt.Chart(...)
