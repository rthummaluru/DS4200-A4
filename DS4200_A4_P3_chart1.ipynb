# %%
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('table3 (2).xlsx')                            #You can also access it directly from github
df.head()   #Will return first 5 rows of the dataset
df
# Out:
#        Land cover types              Location      Area
# 0   NWI marine wetlands                Mystic   1298.80
# 1            Salt marsh                Mystic     46.80
# 2    Freshwater Wetland                Mystic     94.30
# 3            City parks                Mystic   1214.70
# 4                 Beach                Mystic     35.25
# 5            Freshwater                Mystic    786.24
# 6            Oyster bed                Mystic      0.00
# 7               Estuary                Mystic     86.48
# 8            Tidal flat                Mystic      6.68
# 9                Forest                Mystic   4574.30
# 10   Grassland/Openland                Mystic    491.03
# 11        Core habitats                Mystic   1822.92
# 12       Coastal waters                Mystic   5985.33
# 13  NWI marine wetlands  Charles and neponset    671.41
# 14           Salt marsh  Charles and neponset    108.44
# 15   Freshwater Wetland  Charles and neponset     40.80
# 16           City parks  Charles and neponset   4217.98
# 17                Beach  Charles and neponset     40.54
# 18           Freshwater  Charles and neponset    752.14
# 19           Oyster bed  Charles and neponset      0.00
# 20              Estuary  Charles and neponset    115.20
# 21           Tidal flat  Charles and neponset      5.60
# 22               Forest  Charles and neponset  54864.48
# 23   Grassland/Openland  Charles and neponset   1631.93
# 24        Core habitats  Charles and neponset  18031.26
# 25       Coastal waters  Charles and neponset   2800.69
# 26  NWI marine wetlands                  Weir   3990.23
# 27           Salt marsh                  Weir    255.73
# 28   Freshwater Wetland                  Weir     99.92
# 29           City parks                  Weir    790.60
# 30                Beach                  Weir    137.04
# 31           Freshwater                  Weir     33.22
# 32           Oyster bed                  Weir    104.69
# 33              Estuary                  Weir    113.75
# 34           Tidal flat                  Weir     10.00
# 35               Forest                  Weir   5793.51
# 36   Grassland/Openland                  Weir    522.45
# 37        Core habitats                  Weir   5736.91
# 38       Coastal waters                  Weir  10167.73
# 39  NWI marine wetlands               Islands    583.86
# 40           Salt marsh               Islands     11.72
# 41   Freshwater Wetland               Islands     11.18
# 42           City parks               Islands      5.69
# 43                Beach               Islands      0.34
# 44           Freshwater               Islands      0.00
# 45           Oyster bed               Islands      0.00
# 46              Estuary               Islands      0.00
# 47           Tidal flat               Islands      5.60
# 48               Forest               Islands    198.98
# 49   Grassland/Openland               Islands     73.90
# 50        Core habitats               Islands     72.60
# 51       Coastal waters               Islands   9109.77

# %%
# Create the chart
chart = alt.Chart(df).mark_bar().encode(
    x='Land cover types',
    y='Area',
    color='Location'
).properties(
    title='Land cover types by location',
    width=600,
    height=400
)

chart
# Out:
# alt.Chart(...)
