# %%
# libraries
import pandas
import matplotlib.pyplot as plt

# Take the iris dataset
import seaborn as sns
data = sns.load_dataset('iris')

# Make the plot
parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()

# %% [markdown]
# I found this plot to be very interesting because it's unique in that it can plot the relationship between different variables that are completely different from one another. This includes different ranges and even different units. There is a risk of turning the plot into a spaghetti chart, but if this plot is used correctly in its niche use cases, it can be an exteremely informative visualization.
